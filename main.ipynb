# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/datascience/projects/yolo training on sport detection"
# Out:
# /content/drive/MyDrive/datascience/projects/yolo training on sport detection

# %%
# !pwd
# Out:
# /content/drive/MyDrive/datascience/projects/yolo training on sport detection

# %%
# !pip install ultralytics
# Out:
# ...
#   Using cached ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# ...
#    ---------------------------------------- 0.0/978.8 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/978.8 kB ? eta -:--:--
#    ---------------------------------------- 978.8/978.8 kB 2.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    -------------------------- ------------- 1.0/1.6 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 3.0 MB/s eta 0:00:00
# Using cached ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# ...

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !sudo apt-get install libgl1-mesa-glx

# %%
from ultralytics import YOLO

# %%
# Load a pre-trained YOLOv8 model
model = YOLO('yolov8n.pt')  # Start with a small model (you can use 'yolov8s', 'yolov8m', etc.)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 187MB/s]

# %%
results = model.train(
    data='data.yaml',          # Path to your data.yaml file
    epochs=50,                 # Number of training epochs
    imgsz=640,                 # Input image size
    batch=16,                  # Batch size
    device=0                   # Use GPU (device=0) or CPU (device='cpu')
)
# Out:
# Ultralytics 8.3.70 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Evaluate the model on the validation set
metrics = model.val()
# Out:
# Ultralytics 8.3.70 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/datascience/projects/yolo training on sport detection/valid/labels.cache... 7 images, 0 backgrounds, 0 corrupt: 100%|██████████| 7/7 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.69it/s]
#                    all          7          9      0.733      0.848      0.845      0.522
#                batsman          3          3      0.345      0.667      0.394      0.218
#                   luge          2          2      0.585          1      0.995      0.746
#               motorace          2          2          1          1      0.995        0.6
#                 wicket          2          2          1      0.726      0.995      0.522
# ...

# %%
# Export the trained model (optional)
model.export(format='onnx')  # Export to ONNX format
# Out:
# Ultralytics 8.3.70 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.00GHz)
#
# PyTorch: starting from 'runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 9, 8400) (6.0 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxslim', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 240.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.9/142.9 kB 216.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.5/291.5 MB 119.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 170.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 200.6 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 20.2s, installed 3 packages: ['onnx>=1.12.0', 'onnxslim', 'onnxruntime-gpu']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs/detect

# %%
# test model on test dataset useing best.py

model = YOLO('runs/detect/train/weights/best.pt')

# %%
results = model('test/images')
# Out:
# image 1/13 d:\Data Science\projects\yolo training on sport detection\test\images\096_jpg.rf.14fd8ea20630609402fc44715b9cdda3.jpg: 640x640 2 batsmans, 1619.5ms
# image 2/13 d:\Data Science\projects\yolo training on sport detection\test\images\098_jpg.rf.66abf9edfbdb8ccb2d624d8d20929c5c.jpg: 640x640 (no detections), 441.1ms
# image 3/13 d:\Data Science\projects\yolo training on sport detection\test\images\103_jpg.rf.f9e763c940e3605a74687407f787e853.jpg: 640x640 1 batsman, 389.5ms
# image 4/13 d:\Data Science\projects\yolo training on sport detection\test\images\106_jpg.rf.4477a3385d012e42e702df47dde0e179.jpg: 640x640 1 luge, 282.8ms
# image 5/13 d:\Data Science\projects\yolo training on sport detection\test\images\110_jpg.rf.f65febd3f550e6bd1cb8055df5f75711.jpg: 640x640 (no detections), 258.6ms
# image 6/13 d:\Data Science\projects\yolo training on sport detection\test\images\112_jpg.rf.92acb1aa6da63daf819caa45d53c3612.jpg: 640x640 1 javelin, 1 luge, 302.6ms
# ...

# %%
for i in range(len(results)):
  results[i].show()
